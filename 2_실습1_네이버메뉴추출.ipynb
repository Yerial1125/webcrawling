# %% [markdown]
# # 웹크롤링 실습1.

# %% [markdown]
# ### 네이버 메인페이지 메뉴 추출하기

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 크롤링 단계
#
# 1. 크롤링하려는 HTML 페이지의 구조와 코드 살펴보기
#     - F12 (구글 크롬 개발자도구) : URL주소, 태그 확인
# 2. 문서 내용 읽어오기 :
#     - html = urllib.request.urlopen(URL주소).read()
# 3. 원하는 내용 추출하기(parsing)
#     - soup = bs4.BeautifulSoup(html, 'html.parser')
#     - soup.find_all(찾아낼태그)
#     - 동일한 태그가 여러 개인 경우 class 속성 사용

# %% [markdown]
# #### 1. HTML 페이지 구조 살펴보기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - class='group_nav'를 갖는 \<div\>태그 아래 \<ul\>태그들이 메뉴임
#     - class='list_nav type_fix'값을 갖는 \<ul\>태그
#     - class='list_nav NM_FAVORITE_LIST'값을 갖는 \<ul\>태그

# %% [markdown]
# #### 2. 문서 내용 읽어오기

# %% [markdown]
# #### 3. 원하는 태그 추출하기

# %% [markdown]
# - 메뉴1(메일 카페 블로그 지식iN 쇼핑 Pay TV) 추출

# %% [markdown]
# - \<ul\>태그 안의 모든 \<li\> 태그 확인

# %% [markdown]
# - \<li\>태그 내 \<a\>태그의 text 속성을 이용하여 메뉴명 추출

# %% [markdown]
# - 메뉴2(사전 뉴스 증권 부동산 지도 VIBE 도서 웹툰) 추출

# %% [markdown]
# - 전체 메뉴이름 출력

# %% [markdown]
# -----
